# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
iris=pd.read_csv("C:\\Users\\babam\\Downloads\\Iris.csv")

# %%
iris.head()

# %%
iris.describe()

# %%
print("Species=",iris["Species"].unique())

# %%
# !pip install pandas numpy matplotlib plotly scikit-learn

# %%
import plotly.express as px
fig = px.scatter(iris, x="SepalWidthCm", y="SepalLengthCm", color="Species")
fig.show()

# %%
x = iris.drop("Species", axis=1)
y = iris["Species"]

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,
                                                    test_size=0.2,
                                                    random_state=0)

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(x_train, y_train)

# %%
# Drop ID column
x = iris.drop(["Species", "Id"], axis=1)
y = iris["Species"]

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(x_train, y_train)

# Prediction
x_new = pd.DataFrame([[11, 0.9, 1, 0.2]],
                     columns=["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"])
prediction = knn.predict(x_new)
print("Prediction:", prediction)
